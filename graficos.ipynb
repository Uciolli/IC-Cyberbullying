# %%
import numpy as np 
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_odio = pd.read_csv('csvs/tweets_ofensivos_finais_com_ofensa.csv')
df_neutro = pd.read_csv('csvs/tweets_neutros_finais_sem_coisa_nem_ofensa.csv')

# %%
df_neutro.insert(1, 'classe', 0)
df_odio.insert(1, 'classe', 1)
df_geral =  pd.concat([df_odio,df_neutro])

# %%
x = df_geral['classe'].value_counts()
x.plot.bar(color='green')
# Out:
# <AxesSubplot: >

# %%
sns.countplot(x = df_geral['classe'])
# Out:
# <AxesSubplot: xlabel='classe', ylabel='count'>

# %%
# Out:
# 1    6608
# 0    2836
# Name: classe, dtype: int64
